# %% [markdown]
# # Setup quiz
#
# Run the following cell displaying your git info:

# %%
# !git config --list
# Out:
# credential.helper=!f() { /home/vscode/.vscode-server/bin/c3a26841a84f20dfe0850d0a5a9bd01da4f003ea/node /tmp/vscode-remote-containers-b2f955b9-c0c1-4598-900e-744fd33506ce.js git-credential-helper $*; }; f
# credential.https://github.com.helper=
# credential.https://github.com.helper=!/home/linuxbrew/.linuxbrew/bin/gh auth git-credential
# credential.https://gist.github.com.helper=
# credential.https://gist.github.com.helper=!/home/linuxbrew/.linuxbrew/bin/gh auth git-credential
# user.email=maxmiller1204@outlook.com
# user.name=Max
# init.defaultbranch=main
# credential.helper=!f() { /home/vscode/.vscode-server/bin/c3a26841a84f20dfe0850d0a5a9bd01da4f003ea/node /tmp/vscode-remote-containers-b2f955b9-c0c1-4598-900e-744fd33506ce.js git-credential-helper $*; }; f
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://github.com/max-miller1204/QuantumSoftware.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main
# branch.main.vscode-merge-base=origin/main

# %% [markdown]
# Let's see which conda version we have installed

# %%
# !conda --version
# Out:
# conda 24.11.3

# %% [markdown]
# Make sure that you have activated the conda environment you set up for this class, and then execute the following command:

# %%
# !which python
# Out:
# /opt/conda/envs/molssi_best_practices/bin/python

# %% [markdown]
# And which version of Python do you have?

# %%
# !python --version
import sys
assert(sys.version_info.major==3)
assert(sys.version_info.minor>=11)
# Out:
# Python 3.11.14

# %% [markdown]
# Which cookiecutter?

# %%
# !which cookiecutter
# Out:
# /opt/conda/envs/molssi_best_practices/bin/cookiecutter

# %%
# !cookiecutter --version
import cookiecutter
assert(int(cookiecutter._get_version()[0]) >= 2)
# Out:
# Cookiecutter 2.6.0 from /opt/conda/envs/molssi_best_practices/lib/python3.11/site-packages (Python 3.11.14 | packaged by conda-forge | (main, Jan 26 2026, 23:48:32) [GCC 14.3.0])

# %%
# !which jupyter
# Out:
# /opt/conda/envs/molssi_best_practices/bin/jupyter

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 9.10.0
# ipykernel        : 7.2.0
# ipywidgets       : 8.1.8
# jupyter_client   : 8.8.0
# jupyter_core     : 5.9.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.5.5
# nbclient         : 0.10.4
# nbconvert        : 7.17.0
# nbformat         : 5.10.4
# notebook         : 7.5.4
# qtconsole        : 5.7.1
# traitlets        : 5.14.3
