# %% [markdown]
# # Setup quiz
#
# Run the following cell displaying your git info:

# %%
# !git config --list
# Out:
# credential.helper=!f() { /root/.vscode-server/bin/585eba7c0c34fd6b30faac7c62a42050bfbc0086/node /tmp/vscode-remote-containers-1543ede9-13e5-4a61-8ee2-d9aa0670ae56.js git-credential-helper $*; }; f
# alias.co=checkout
# alias.br=branch
# alias.ci=commit
# alias.st=status
# init.defaultbranch=master
# pull.rebase=true
# push.autosetupremote=true
# diff.algorithm=histogram
# diff.colormoved=plain
# diff.mnemonicprefix=true
# commit.verbose=true
# column.ui=auto
# branch.sort=-committerdate
# tag.sort=-version:refname
# rerere.enabled=true
# rerere.autoupdate=true
# user.name=Max Miller
# user.email=maxmiller1204@outlook.com
# credential.https://github.com.helper=
# credential.https://github.com.helper=!/usr/bin/gh auth git-credential
# credential.https://gist.github.com.helper=
# credential.https://gist.github.com.helper=!/usr/bin/gh auth git-credential
# credential.helper=!f() { /root/.vscode-server/bin/585eba7c0c34fd6b30faac7c62a42050bfbc0086/node /tmp/vscode-remote-containers-1543ede9-13e5-4a61-8ee2-d9aa0670ae56.js git-credential-helper $*; }; f
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://github.com/CHEM-PHYS-X684/QuantumSoftware.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main
# branch.main.vscode-merge-base=origin/main

# %% [markdown]
# Let's see which conda version we have installed

# %%
# !conda --version
# Out:
# conda 23.10.0

# %% [markdown]
# Make sure that you have activated the conda environment you set up for this class, and then execute the following command:

# %%
# !which python
# Out:
# /opt/conda/envs/molssi_best_practices/bin/python

# %% [markdown]
# And which version of Python do you have?

# %%
# !python --version
import sys
assert(sys.version_info.major==3)
assert(sys.version_info.minor>=11)
# Out:
# Python 3.11.0

# %% [markdown]
# Which cookiecutter?

# %%
# !which cookiecutter
# Out:
# /opt/conda/envs/molssi_best_practices/bin/cookiecutter

# %%
# !cookiecutter --version
import cookiecutter
assert(int(cookiecutter._get_version()[0]) >= 2)
# Out:
# Cookiecutter 2.5.0 from /opt/conda/envs/molssi_best_practices/lib/python3.11/site-packages (Python 3.11.0 | packaged by conda-forge | (main, Jan 14 2023, 12:27:40) [GCC 11.3.0])

# %%
# !which jupyter
# Out:
# /opt/conda/envs/molssi_best_practices/bin/jupyter

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.19.0
# ipykernel        : 7.1.0
# ipywidgets       : 8.1.8
# jupyter_client   : 8.6.3
# jupyter_core     : 5.9.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.5.2
# nbclient         : 0.10.4
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.5.2
# qtconsole        : 5.7.0
# traitlets        : 5.14.1
